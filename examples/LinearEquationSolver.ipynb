# %%
import numpy as np
from lineq.lu_decomposition import lu_solve

# %%
A = np.array([
        [3.,0.,1.,0.],
        [0.,1.,0.,1.],
        [0.,0.,2.,1.],
        [1.,0.,1.,0.],
        
])
b = np.array([[1.],[2.],[2.],[4.]])

# %%
x = lu_solve(A, b)

# %%
target = np.linalg.solve(A, b)

# %%
x, target
# Out:
# (array([-1.5, 11. ,  5.5, -9. ]),
#  array([[-1.5],
#         [11. ],
#         [ 5.5],
#         [-9. ]]))
