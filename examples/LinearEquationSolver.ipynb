# %%
import numpy as np
from lineq.gauss import gauss_elimination

# %%
A = np.array([
        [3.,0.,1.,0.],
        [0.,3.,2.,1.],
        [1.,0.,1.,0.],
        [0.,1.,0.,1.]
])
b = np.array([[1.],[4.],[2.],[2.]])

# %%
x = gauss_elimination(A, b)

# %%
print(x)
# Out:
# [-0.5 -1.5  2.5  3.5]
