# %%
import numpy as np
import matplotlib.pyplot as plt

from interpolation.polynomial import get_interpolating_polynomial

# %%
xs = np.array([1., 2., 3., 4.])
ys = np.array([0., 2., 1., 3.])

# %%
interpolating_polynomial = get_interpolating_polynomial(xs, ys)

# %%
ts = np.arange(xs[0], xs[-1], 0.002)
plt.scatter(xs, ys)
plt.plot(ts, interpolating_polynomial(ts))
