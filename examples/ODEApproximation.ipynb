# %%
from ode.approximate import eulers_method, implicit_euler_method

# %%
def delta_y(t, y):
    return 2 * y

# %%
eulers_method(0, 1, delta_y, 0.1, 1), eulers_method(0, 1, delta_y, 0.1, 2)
# Out:
# (6.191736422399999, 38.337599924474745)

# %%
implicit_euler_method(0, 1, delta_y, 0.1, 1), implicit_euler_method(0, 1, delta_y, 0.1, 2)
# Out:
# (9.313225746154783, 86.73617379884026)
