# %%
import numpy as np
import matplotlib.pyplot as plt
from misc import Polynom
from interpolation.splines import interpolate_with_splines

# %%
xs = np.array([1, 2, 3, 4, 5, 6, 7])
ys = np.array([1, 2, 3, 8, 16, 32, 1])

# %%
interpolation_func = interpolate_with_splines(xs, ys)

# %%
ts = np.arange(xs[0], xs[-1], 0.02)
plt.plot(ts, (np.vectorize(interpolation_func)(ts)))
plt.scatter(xs, ys)
