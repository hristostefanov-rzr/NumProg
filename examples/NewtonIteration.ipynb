# %%
import numpy as np
import matplotlib.pyplot as plt

from misc import Polynomial
from iteration.newton import newton_method_polynomial

# %%
p = Polynomial([-1,0,-2,1])

# %%
x = newton_method_polynomial(p, 1, 1)

# %%
ts = np.arange(-2, 3, 0.002)
plt.scatter(x, p(x))
plt.plot(ts, p(ts))
plt.plot(ts, np.zeros(len(ts)))
